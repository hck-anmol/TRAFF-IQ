# %%
from ultralytics import YOLO

# Load a pre-trained model
model = YOLO('yolov8n.pt')

# Train the model using the LOCAL path to your data.yaml file
# This path is relative to the root of your 'hackathon_ai' folder
results = model.train(data='emergency_vehicles_dataset/data.yaml', 
                      epochs=50, 
                      imgsz=640)

print("Training complete! Your model is saved in the 'runs' folder.")
# Out:
# ...
# Ultralytics 8.3.209  Python-3.13.3 torch-2.8.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# ...
